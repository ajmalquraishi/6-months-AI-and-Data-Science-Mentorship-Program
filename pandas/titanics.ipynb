# %% [markdown]
# ## Data Saturation
# Developed by Ajmal Quraishi\
# Date: 22-oct-2023\
# E-mail: ajmalquraishi98@gmail.com

# %%
import pandas as pd
import seaborn as sns

titanic = sns.load_dataset('titanic')
df = titanic
df.dtypes[df.dtypes == 'object']
titanic[['pclass', 'survived', 'sex', 'age', 'sibsp', 'parch', 'embarked']]
# Out:
#      pclass  survived     sex   age  sibsp  parch embarked
# 0         3         0    male  22.0      1      0        S
# 1         1         1  female  38.0      1      0        C
# 2         3         1  female  26.0      0      0        S
# 3         1         1  female  35.0      1      0        S
# 4         3         0    male  35.0      0      0        S
# ..      ...       ...     ...   ...    ...    ...      ...
# 886       2         0    male  27.0      0      0        S
# 887       1         1  female  19.0      0      0        S
# 888       3         0  female   NaN      1      2        S
# 889       1         1    male  26.0      0      0        C
# 890       3         0    male  32.0      0      0        Q
#
# [891 rows x 7 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Ajmal Quraishi\Desktop\6 months AI and Data Science Mentorship Program\pandas\titanics.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Ajmal%20Quraishi/Desktop/6%20months%20AI%20and%20Data%20Science%20Mentorship%20Program/pandas/titanics.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> df[['Name','Sex','Age']]
#
# NameError: name 'df' is not defined
